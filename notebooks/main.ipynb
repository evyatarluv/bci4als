# %% [markdown]
# # Motor Imagery Left/Right Classification Using Machine Learning
# ## BCI-4-ALS, Ben Gurion University, 2020
# ## Evyatar Luvaton, Noam Siegel

# %%
import mne
import os
import numpy as np
import pyxdf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pickle

# %%
print(os.getcwd())
x_1 = np.genfromtxt('..\\data\\noam\\1\\features.csv', delimiter=',')
x_2 = np.genfromtxt('..\\data\\noam\\2\\features.csv', delimiter=',')
x_3 = np.genfromtxt('..\\data\\noam\\3\\features.csv', delimiter=',')

plt.matshow(x_1)
plt.title('C03, C04 - PSD')
plt.show()
# Out:
# C:\Users\lenovo\PycharmProjects\BCI-4-ALS\notebooks

# %%
plt.matshow(x_2)
plt.title('C03, C04 - PSD')
plt.show()

# %%
plt.matshow(x_3)
plt.title('C03, C04 - PSD')
plt.show()
